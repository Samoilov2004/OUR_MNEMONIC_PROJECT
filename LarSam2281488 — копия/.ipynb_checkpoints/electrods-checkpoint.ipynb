# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Читаем файл с использованием пробелов в качестве разделителя
df1 = pd.read_csv('/Users/mihail/Desktop/LarSam2281488/first.tsv', sep=r'\s+', header=None)

# Преобразуем тип столбцов в float64
df1 = data.astype('float64')

"""
df[0] - время в с
df[1] - потенциал
df[2] - 
"""

df_help = pd.DataFrame({'min':df.min(), 'max':df.max()})
df_help
# Out:
#           min       max
# 0      0.1246  150.4318
# 1  -1499.1000   -0.2339
# 2 -72246.0000 -511.8600

# %%
# Читаем файл с использованием пробелов в качестве разделителя
df2 = pd.read_csv('/Users/mihail/Desktop/LarSam2281488/second.tsv', sep=r'\s+', header=None)

# Преобразуем тип столбцов в float64
df2 = data.astype('float64')

# %%
plt.plot(df1[1], df1[2])
plt.plot(df2[1], df2[2])
